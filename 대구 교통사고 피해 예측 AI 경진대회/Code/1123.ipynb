# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv('./data/train.csv')
test_data = pd.read_csv('./data/test.csv')

# %%
import holidays

kor_holiday = list(holidays.KOR(years = range(2019,2023)).keys())

temp_df = pd.DataFrame()
temp_df['사고일시'] = kor_holiday
temp_df['holiday'] = 1
temp_df.사고일시 = pd.to_datetime(temp_df.사고일시)

temp_df['day'] = temp_df.사고일시.dt.day
temp_df['month'] = temp_df.사고일시.dt.month
temp_df['year'] = temp_df.사고일시.dt.year

temp_df = temp_df.drop(columns='사고일시')

# %%
train_data['사고일시'] = pd.to_datetime(train_data['사고일시'])
test_data['사고일시'] = pd.to_datetime(test_data['사고일시'])

# %%
for df in [train_data,test_data]:
    df['hour'] = df.사고일시.dt.hour
    df['weekday'] = df.사고일시.dt.weekday
    df['day'] = df.사고일시.dt.day
    df['month'] = df.사고일시.dt.month
    df['year'] = df.사고일시.dt.year
    df['gu'] = df.시군구.apply(lambda x:x.split()[1])
    df['dong'] = df.시군구.apply(lambda x:x.split()[2])
    df['road1'] = df.도로형태.apply(lambda x:x.split()[0])
    df['road2'] = df.도로형태.apply(lambda x:x.split()[2])

# %%
train_data = pd.merge(train_data,temp_df,how = 'left',on =['day','month','year'])
test_data = pd.merge(test_data,temp_df,how = 'left',on =['day','month','year'])
train_data.holiday = train_data.holiday.fillna(0)
test_data.holiday = test_data.holiday.fillna(0)

# %%
train_data.loc[train_data['weekday'] >= 5, 'holiday'] = 1
test_data.loc[test_data['weekday'] >= 5, 'holiday'] = 1

# %%
train_data['시간대'] = train_data.hour.apply(lambda x:0 if 1<=x<7 else 1 if 7<=x<13 else 2 if 13<=x<19 else 3)
test_data['시간대'] = test_data.hour.apply(lambda x:0 if 1<=x<7 else 1 if 7<=x<13 else 2 if 13<=x<19 else 3)

# %%
train_data = pd.merge(train_data,train_data.groupby('dong')['gu'].count().reset_index().rename(columns={'gu':'acci_cnt'}),how='left',on='dong')
test_data = pd.merge(test_data,train_data.groupby('dong')['gu'].count().reset_index().rename(columns={'gu':'acci_cnt'}),how='left',on='dong')
# train_data = pd.merge(train_data,train_data.groupby('dong')['ECLO'].sum().reset_index().rename(columns={'ECLO':'acci'}),how='left',on='dong')
# test_data = pd.merge(test_data,train_data.groupby('dong')['ECLO'].sum().reset_index().rename(columns={'ECLO':'acci'}),how='left',on='dong')

# %%
group = ['dong']
result = ['사망자수', '중상자수', '경상자수', '부상자수']
for gr in group:
    for i in result:
        # train_data = pd.merge(train_data,train_data.groupby(f'dong')[f'{i}'].count().reset_index().rename(columns={f'{i}':f'{i}_{gr}_cnt'}),how='left',on=f'{gr}')
        # test_data = pd.merge(test_data,train_data.groupby(f'{gr}')[f'{i}'].count().reset_index().rename(columns={f'{i}':f'{i}_{gr}_cnt'}),how='left',on=f'{gr}')
        # train_data = pd.merge(train_data,train_data.groupby(f'{gr}')[f'{i}'].mean().reset_index().rename(columns={f'{i}':f'{i}_{gr}_mean'}),how='left',on=f'{gr}')
        # test_data = pd.merge(test_data,train_data.groupby(f'{gr}')[f'{i}'].mean().reset_index().rename(columns={f'{i}':f'{i}_{gr}_mean'}),how='left',on=f'{gr}')
        train_data = pd.merge(train_data,train_data.groupby(f'{gr}')[f'{i}'].sum().reset_index().rename(columns={f'{i}':f'{i}_{gr}_sum'}),how='left',on=f'{gr}')
        test_data = pd.merge(test_data,train_data.groupby(f'{gr}')[f'{i}'].sum().reset_index().rename(columns={f'{i}':f'{i}_{gr}_sum'}),how='left',on=f'{gr}')
# for i in result:
#     train_data = pd.merge(train_data,train_data.groupby(['시간대','holiday'])[f'{i}'].count().reset_index().rename(columns={f'{i}':f'{i}_tt_cnt'}),how='left',on=['시간대','holiday'])
#     test_data = pd.merge(test_data,train_data.groupby(['시간대','holiday'])[f'{i}'].count().reset_index().rename(columns={f'{i}':f'{i}_tt_cnt'}),how='left',on=['시간대','holiday'])
#     train_data = pd.merge(train_data,train_data.groupby(['시간대','holiday'])[f'{i}'].mean().reset_index().rename(columns={f'{i}':f'{i}_tt_mean'}),how='left',on=['시간대','holiday'])
#     test_data = pd.merge(test_data,train_data.groupby(['시간대','holiday'])[f'{i}'].mean().reset_index().rename(columns={f'{i}':f'{i}_tt_mean'}),how='left',on=['시간대','holiday'])
    # train_data = pd.merge(train_data,train_data.groupby(['시간대','holiday'])[f'{i}'].sum().reset_index().rename(columns={f'{i}':f'{i}_tt_sum'}),how='left',on=['시간대','holiday'])
    # test_data = pd.merge(test_data,train_data.groupby(['시간대','holiday'])[f'{i}'].sum().reset_index().rename(columns={f'{i}':f'{i}_tt_sum'}),how='left',on=['시간대','holiday'])
# for i in result:
#     train_data = pd.merge(train_data,train_data.groupby(['dong','holiday'])[f'{i}'].count().reset_index().rename(columns={f'{i}':f'{i}_aa_cnt'}),how='left',on=['dong','holiday'])
#     test_data = pd.merge(test_data,train_data.groupby(['dong','holiday'])[f'{i}'].count().reset_index().rename(columns={f'{i}':f'{i}_aa_cnt'}),how='left',on=['dong','holiday'])
#     train_data = pd.merge(train_data,train_data.groupby(['dong','holiday'])[f'{i}'].mean().reset_index().rename(columns={f'{i}':f'{i}_aa_mean'}),how='left',on=['dong','holiday'])
#     test_data = pd.merge(test_data,train_data.groupby(['dong','holiday'])[f'{i}'].mean().reset_index().rename(columns={f'{i}':f'{i}_aa_mean'}),how='left',on=['dong','holiday'])
    # train_data = pd.merge(train_data,train_data.groupby(['dong','holiday'])[f'{i}'].sum().reset_index().rename(columns={f'{i}':f'{i}_aa_sum'}),how='left',on=['dong','holiday'])
    # test_data = pd.merge(test_data,train_data.groupby(['dong','holiday'])[f'{i}'].sum().reset_index().rename(columns={f'{i}':f'{i}_aa_sum'}),how='left',on=['dong','holiday'])
# for i in result:
#     train_data = pd.merge(train_data,train_data.groupby(['dong','holiday','road1'])[f'{i}'].count().reset_index().rename(columns={f'{i}':f'{i}_bb_cnt'}),how='left',on=['dong','holiday','road1'])
#     test_data = pd.merge(test_data,train_data.groupby(['dong','holiday','road1'])[f'{i}'].count().reset_index().rename(columns={f'{i}':f'{i}_bb_cnt'}),how='left',on=['dong','holiday','road1'])
#     train_data = pd.merge(train_data,train_data.groupby(['dong','holiday','road1'])[f'{i}'].mean().reset_index().rename(columns={f'{i}':f'{i}_bb_mean'}),how='left',on=['dong','holiday','road1'])
#     test_data = pd.merge(test_data,train_data.groupby(['dong','holiday','road1'])[f'{i}'].mean().reset_index().rename(columns={f'{i}':f'{i}_bb_mean'}),how='left',on=['dong','holiday','road1'])
#     train_data = pd.merge(train_data,train_data.groupby(['dong','holiday','road1'])[f'{i}'].sum().reset_index().rename(columns={f'{i}':f'{i}_bb_sum'}),how='left',on=['dong','holiday','road1'])
#     test_data = pd.merge(test_data,train_data.groupby(['dong','holiday','road1'])[f'{i}'].sum().reset_index().rename(columns={f'{i}':f'{i}_bb_sum'}),how='left',on=['dong','holiday','road1'])
# for i in result:
#     train_data = pd.merge(train_data,train_data.groupby(['시간대','holiday','road1'])[f'{i}'].count().reset_index().rename(columns={f'{i}':f'{i}_cc_cnt'}),how='left',on=['시간대','holiday','road1'])
#     test_data = pd.merge(test_data,train_data.groupby(['시간대','holiday','road1'])[f'{i}'].count().reset_index().rename(columns={f'{i}':f'{i}_cc_cnt'}),how='left',on=['시간대','holiday','road1'])
#     train_data = pd.merge(train_data,train_data.groupby(['시간대','holiday','road1'])[f'{i}'].mean().reset_index().rename(columns={f'{i}':f'{i}_cc_mean'}),how='left',on=['시간대','holiday','road1'])
#     test_data = pd.merge(test_data,train_data.groupby(['시간대','holiday','road1'])[f'{i}'].mean().reset_index().rename(columns={f'{i}':f'{i}_cc_mean'}),how='left',on=['시간대','holiday','road1'])
#     train_data = pd.merge(train_data,train_data.groupby(['시간대','holiday','road1'])[f'{i}'].sum().reset_index().rename(columns={f'{i}':f'{i}_cc_sum'}),how='left',on=['시간대','holiday','road1'])
#     test_data = pd.merge(test_data,train_data.groupby(['시간대','holiday','road1'])[f'{i}'].sum().reset_index().rename(columns={f'{i}':f'{i}_cc_sum'}),how='left',on=['시간대','holiday','road1'])

# %%
train_data['serious_ratio'] = (train_data['사망자수_dong_sum']+train_data['중상자수_dong_sum'])/train_data.acci_cnt
test_data['serious_ratio'] = (test_data['사망자수_dong_sum']+test_data['중상자수_dong_sum'])/test_data.acci_cnt

# %%
train_data.columns
# Out:
# Index(['ID', '사고일시', '요일', '기상상태', '시군구', '도로형태', '노면상태', '사고유형',
#        '사고유형 - 세부분류', '법규위반', '가해운전자 차종', '가해운전자 성별', '가해운전자 연령', '가해운전자 상해정도',
#        '피해운전자 차종', '피해운전자 성별', '피해운전자 연령', '피해운전자 상해정도', '사망자수', '중상자수',
#        '경상자수', '부상자수', 'ECLO', 'hour', 'weekday', 'day', 'month', 'year', 'gu',
#        'dong', 'road1', 'road2', 'holiday', '시간대', 'acci_cnt', '사망자수_dong_sum',
#        '중상자수_dong_sum', '경상자수_dong_sum', '부상자수_dong_sum', 'serious_ratio'],
#       dtype='object')

# %%
test_x = test_data.drop(columns = ['ID','사고일시','요일','시군구','도로형태','weekday']).copy()
train_x = train_data[test_x.columns].copy()
train_y = train_data['ECLO'].copy()

# %%
from sklearn.preprocessing import LabelEncoder

categorical_features = list(train_x.dtypes[train_x.dtypes == "object"].index)
# 추출된 문자열 변수 확인
display(categorical_features)

for i in categorical_features:
    le = LabelEncoder()
    le=le.fit(train_x[i]) 
    train_x[i]=le.transform(train_x[i])
    
    for case in np.unique(test_x[i]):
        if case not in le.classes_: 
            le.classes_ = np.append(le.classes_, case) 
    test_x[i]=le.transform(test_x[i])
    
display(train_x.head())
display(test_x.head())
# Out:
# ['기상상태', '노면상태', '사고유형', 'gu', 'dong', 'road1', 'road2']
#    기상상태  노면상태  사고유형  hour  day  month  year  gu  dong  road1  road2  holiday  \
# 0     2     0     0     0    1      1  2019   7    40      2      5      1.0
# 1     5     0     0     0    1      1  2019   1     4      2      5      1.0
# 2     2     0     0     1    1      1  2019   6    66      2      5      1.0
# 3     2     0     1     2    1      1  2019   4    79      2      5      1.0
# 4     2     0     1     4    1      1  2019   3   129      2      5      1.0
#
#    시간대  acci_cnt  사망자수_dong_sum  중상자수_dong_sum  경상자수_dong_sum  부상자수_dong_sum  \
# 0    3       131              3             31            116             28
# 1    3       678              3            148            790             73
# 2    0       604              0            145            708             76
# 3    0       426              1             90            422             67
# 4    0       825              3            205            862            112
#
#    serious_ratio
# 0       0.259542
# 1       0.222714
# 2       0.240066
# 3       0.213615
# 4       0.252121
#    기상상태  노면상태  사고유형  hour  day  month  year  gu  dong  road1  road2  holiday  \
# 0     2     0     0     1    1      1  2022   6    99      0      3      1.0
# 1     2     0     0     1    1      1  2022   6   168      2      5      1.0
# 2     2     0     1     4    1      1  2022   6   117      0      3      1.0
# 3     2     0     1     4    1      1  2022   6   126      2      5      1.0
# 4     2     0     1     6    1      1  2022   1     4      0      3      1.0
#
#    시간대  acci_cnt  사망자수_dong_sum  중상자수_dong_sum  경상자수_dong_sum  부상자수_dong_sum  \
# 0    0       338              2             91            381             32
# 1    0       492              1            145            484             58
# 2    0       147              0             43            165             17
# 3    0       372              3             74            401             48
# 4    0       678              3            148            790             73
#
#    serious_ratio
# 0       0.275148
# 1       0.296748
# 2       0.292517
# 3       0.206989
# 4       0.222714

# %%
df = pd.DataFrame()
from sklearn.metrics import mean_squared_log_error
from lightgbm import log_evaluation, early_stopping, LGBMRegressor
from sklearn.model_selection import KFold

kf = KFold(n_splits = 5, shuffle = True, random_state = 0)

model = LGBMRegressor(random_state = 42)
X_train = train_x
y_train = np.log1p(train_y)
X_test = test_x
prediction = np.zeros((X_test.shape[0]))
rmsle_list = []
cnt = 0
for tr_idx, val_idx in kf.split(X_train, y_train):
    tr_x, tr_y = X_train.iloc[tr_idx], y_train.iloc[tr_idx]
    val_x, val_y = X_train.iloc[val_idx], y_train.iloc[val_idx]
    model.fit(tr_x, tr_y, eval_set=(val_x, val_y),eval_metric='RMSE',callbacks=[early_stopping(stopping_rounds=50),log_evaluation()])
    pred = model.predict(val_x)

    rmsle = np.sqrt(mean_squared_log_error(np.expm1(val_y), np.expm1(pred)))
    rmsle_list.append(rmsle)
    
    sub_pred = np.array(model.predict(X_test)) / 5
    prediction += sub_pred
print(f'{model.__class__.__name__}의 5fold 평균 RMSLE는 {np.mean(rmsle_list)}')
# Out:
# [1]	valid_0's rmse: 0.451415	valid_0's l2: 0.203776
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's rmse: 0.450224	valid_0's l2: 0.202701
# [3]	valid_0's rmse: 0.449317	valid_0's l2: 0.201886
# [4]	valid_0's rmse: 0.448564	valid_0's l2: 0.20121
# [5]	valid_0's rmse: 0.447955	valid_0's l2: 0.200664
# [6]	valid_0's rmse: 0.447431	valid_0's l2: 0.200195
# [7]	valid_0's rmse: 0.446988	valid_0's l2: 0.199798
# [8]	valid_0's rmse: 0.446603	valid_0's l2: 0.199454
# [9]	valid_0's rmse: 0.446381	valid_0's l2: 0.199256
# [10]	valid_0's rmse: 0.446134	valid_0's l2: 0.199036
# [11]	valid_0's rmse: 0.445926	valid_0's l2: 0.19885
# [12]	valid_0's rmse: 0.445751	valid_0's l2: 0.198694
# [13]	valid_0's rmse: 0.445486	valid_0's l2: 0.198458
# [14]	valid_0's rmse: 0.445346	valid_0's l2: 0.198333
# [15]	valid_0's rmse: 0.445196	valid_0's l2: 0.1982
# [16]	valid_0's rmse: 0.445111	valid_0's l2: 0.198124
# [17]	valid_0's rmse: 0.445061	valid_0's l2: 0.198079
# [18]	valid_0's rmse: 0.445021	valid_0's l2: 0.198044
# [19]	valid_0's rmse: 0.44491	valid_0's l2: 0.197945
# [20]	valid_0's rmse: 0.444867	valid_0's l2: 0.197907
# [21]	valid_0's rmse: 0.444884	valid_0's l2: 0.197921
# [22]	valid_0's rmse: 0.444922	valid_0's l2: 0.197955
# [23]	valid_0's rmse: 0.444878	valid_0's l2: 0.197916
# [24]	valid_0's rmse: 0.444804	valid_0's l2: 0.197851
# [25]	valid_0's rmse: 0.44487	valid_0's l2: 0.19791
# [26]	valid_0's rmse: 0.444927	valid_0's l2: 0.19796
# [27]	valid_0's rmse: 0.44494	valid_0's l2: 0.197971
# [28]	valid_0's rmse: 0.444958	valid_0's l2: 0.197988
# [29]	valid_0's rmse: 0.445008	valid_0's l2: 0.198032
# [30]	valid_0's rmse: 0.445008	valid_0's l2: 0.198032
# [31]	valid_0's rmse: 0.44495	valid_0's l2: 0.197981
# [32]	valid_0's rmse: 0.44492	valid_0's l2: 0.197954
# [33]	valid_0's rmse: 0.44497	valid_0's l2: 0.197998
# [34]	valid_0's rmse: 0.445023	valid_0's l2: 0.198046
# [35]	valid_0's rmse: 0.445034	valid_0's l2: 0.198056
# [36]	valid_0's rmse: 0.44506	valid_0's l2: 0.198079
# [37]	valid_0's rmse: 0.445081	valid_0's l2: 0.198097
# [38]	valid_0's rmse: 0.44513	valid_0's l2: 0.19814
# [39]	valid_0's rmse: 0.445158	valid_0's l2: 0.198165
# [40]	valid_0's rmse: 0.445156	valid_0's l2: 0.198163
# [41]	valid_0's rmse: 0.445239	valid_0's l2: 0.198238
# [42]	valid_0's rmse: 0.445288	valid_0's l2: 0.198281
# [43]	valid_0's rmse: 0.445376	valid_0's l2: 0.19836
# [44]	valid_0's rmse: 0.445406	valid_0's l2: 0.198387
# [45]	valid_0's rmse: 0.445488	valid_0's l2: 0.19846
# [46]	valid_0's rmse: 0.445501	valid_0's l2: 0.198471
# [47]	valid_0's rmse: 0.445496	valid_0's l2: 0.198467
# [48]	valid_0's rmse: 0.445477	valid_0's l2: 0.198449
# [49]	valid_0's rmse: 0.445485	valid_0's l2: 0.198457
# [50]	valid_0's rmse: 0.445503	valid_0's l2: 0.198473
# [51]	valid_0's rmse: 0.445483	valid_0's l2: 0.198455
# [52]	valid_0's rmse: 0.445526	valid_0's l2: 0.198493
# [53]	valid_0's rmse: 0.445506	valid_0's l2: 0.198476
# [54]	valid_0's rmse: 0.445484	valid_0's l2: 0.198456
# [55]	valid_0's rmse: 0.445486	valid_0's l2: 0.198457
# [56]	valid_0's rmse: 0.445524	valid_0's l2: 0.198492
# [57]	valid_0's rmse: 0.445534	valid_0's l2: 0.1985
# [58]	valid_0's rmse: 0.445519	valid_0's l2: 0.198487
# [59]	valid_0's rmse: 0.44553	valid_0's l2: 0.198497
# [60]	valid_0's rmse: 0.445546	valid_0's l2: 0.198511
# [61]	valid_0's rmse: 0.445562	valid_0's l2: 0.198525
# [62]	valid_0's rmse: 0.445498	valid_0's l2: 0.198469
# [63]	valid_0's rmse: 0.445433	valid_0's l2: 0.19841
# [64]	valid_0's rmse: 0.445446	valid_0's l2: 0.198422
# [65]	valid_0's rmse: 0.445467	valid_0's l2: 0.198441
# [66]	valid_0's rmse: 0.445476	valid_0's l2: 0.198449
# [67]	valid_0's rmse: 0.445502	valid_0's l2: 0.198472
# [68]	valid_0's rmse: 0.445586	valid_0's l2: 0.198547
# [69]	valid_0's rmse: 0.44562	valid_0's l2: 0.198577
# [70]	valid_0's rmse: 0.44559	valid_0's l2: 0.19855
# [71]	valid_0's rmse: 0.445578	valid_0's l2: 0.19854
# [72]	valid_0's rmse: 0.445578	valid_0's l2: 0.19854
# [73]	valid_0's rmse: 0.445564	valid_0's l2: 0.198527
# [74]	valid_0's rmse: 0.445565	valid_0's l2: 0.198528
# Early stopping, best iteration is:
# [24]	valid_0's rmse: 0.444804	valid_0's l2: 0.197851
# [1]	valid_0's rmse: 0.446374	valid_0's l2: 0.19925
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's rmse: 0.445481	valid_0's l2: 0.198453
# [3]	valid_0's rmse: 0.444703	valid_0's l2: 0.197761
# [4]	valid_0's rmse: 0.444098	valid_0's l2: 0.197223
# [5]	valid_0's rmse: 0.443592	valid_0's l2: 0.196774
# [6]	valid_0's rmse: 0.443176	valid_0's l2: 0.196405
# [7]	valid_0's rmse: 0.442857	valid_0's l2: 0.196122
# [8]	valid_0's rmse: 0.442649	valid_0's l2: 0.195939
# [9]	valid_0's rmse: 0.442531	valid_0's l2: 0.195833
# [10]	valid_0's rmse: 0.442418	valid_0's l2: 0.195733
# [11]	valid_0's rmse: 0.442329	valid_0's l2: 0.195655
# [12]	valid_0's rmse: 0.442235	valid_0's l2: 0.195572
# [13]	valid_0's rmse: 0.442189	valid_0's l2: 0.195531
# [14]	valid_0's rmse: 0.442159	valid_0's l2: 0.195505
# [15]	valid_0's rmse: 0.442215	valid_0's l2: 0.195554
# [16]	valid_0's rmse: 0.442233	valid_0's l2: 0.19557
# [17]	valid_0's rmse: 0.44226	valid_0's l2: 0.195594
# [18]	valid_0's rmse: 0.442326	valid_0's l2: 0.195653
# [19]	valid_0's rmse: 0.44234	valid_0's l2: 0.195665
# [20]	valid_0's rmse: 0.442358	valid_0's l2: 0.195681
# [21]	valid_0's rmse: 0.442261	valid_0's l2: 0.195595
# [22]	valid_0's rmse: 0.442236	valid_0's l2: 0.195572
# [23]	valid_0's rmse: 0.442305	valid_0's l2: 0.195633
# [24]	valid_0's rmse: 0.442343	valid_0's l2: 0.195667
# [25]	valid_0's rmse: 0.442293	valid_0's l2: 0.195623
# [26]	valid_0's rmse: 0.442275	valid_0's l2: 0.195607
# [27]	valid_0's rmse: 0.442328	valid_0's l2: 0.195654
# [28]	valid_0's rmse: 0.442271	valid_0's l2: 0.195604
# [29]	valid_0's rmse: 0.442289	valid_0's l2: 0.195619
# [30]	valid_0's rmse: 0.442296	valid_0's l2: 0.195626
# [31]	valid_0's rmse: 0.44229	valid_0's l2: 0.19562
# [32]	valid_0's rmse: 0.442202	valid_0's l2: 0.195543
# [33]	valid_0's rmse: 0.442225	valid_0's l2: 0.195563
# [34]	valid_0's rmse: 0.442272	valid_0's l2: 0.195605
# [35]	valid_0's rmse: 0.442225	valid_0's l2: 0.195563
# [36]	valid_0's rmse: 0.44231	valid_0's l2: 0.195638
# [37]	valid_0's rmse: 0.442349	valid_0's l2: 0.195673
# [38]	valid_0's rmse: 0.442357	valid_0's l2: 0.19568
# [39]	valid_0's rmse: 0.442315	valid_0's l2: 0.195643
# [40]	valid_0's rmse: 0.442352	valid_0's l2: 0.195675
# [41]	valid_0's rmse: 0.442381	valid_0's l2: 0.195701
# [42]	valid_0's rmse: 0.442418	valid_0's l2: 0.195734
# [43]	valid_0's rmse: 0.442482	valid_0's l2: 0.19579
# [44]	valid_0's rmse: 0.442508	valid_0's l2: 0.195813
# [45]	valid_0's rmse: 0.442534	valid_0's l2: 0.195836
# [46]	valid_0's rmse: 0.44254	valid_0's l2: 0.195842
# [47]	valid_0's rmse: 0.442553	valid_0's l2: 0.195853
# [48]	valid_0's rmse: 0.442568	valid_0's l2: 0.195866
# [49]	valid_0's rmse: 0.44264	valid_0's l2: 0.19593
# [50]	valid_0's rmse: 0.442706	valid_0's l2: 0.195989
# [51]	valid_0's rmse: 0.44271	valid_0's l2: 0.195992
# [52]	valid_0's rmse: 0.442701	valid_0's l2: 0.195984
# [53]	valid_0's rmse: 0.442691	valid_0's l2: 0.195976
# [54]	valid_0's rmse: 0.442677	valid_0's l2: 0.195963
# [55]	valid_0's rmse: 0.442711	valid_0's l2: 0.195993
# [56]	valid_0's rmse: 0.442773	valid_0's l2: 0.196048
# [57]	valid_0's rmse: 0.442803	valid_0's l2: 0.196075
# [58]	valid_0's rmse: 0.442818	valid_0's l2: 0.196088
# [59]	valid_0's rmse: 0.442818	valid_0's l2: 0.196088
# [60]	valid_0's rmse: 0.442848	valid_0's l2: 0.196114
# [61]	valid_0's rmse: 0.442837	valid_0's l2: 0.196104
# [62]	valid_0's rmse: 0.442911	valid_0's l2: 0.19617
# [63]	valid_0's rmse: 0.442936	valid_0's l2: 0.196192
# [64]	valid_0's rmse: 0.44299	valid_0's l2: 0.19624
# Early stopping, best iteration is:
# [14]	valid_0's rmse: 0.442159	valid_0's l2: 0.195505
# [1]	valid_0's rmse: 0.45512	valid_0's l2: 0.207134
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's rmse: 0.45393	valid_0's l2: 0.206052
# [3]	valid_0's rmse: 0.452869	valid_0's l2: 0.205091
# [4]	valid_0's rmse: 0.452037	valid_0's l2: 0.204338
# [5]	valid_0's rmse: 0.451376	valid_0's l2: 0.20374
# [6]	valid_0's rmse: 0.450806	valid_0's l2: 0.203226
# [7]	valid_0's rmse: 0.450311	valid_0's l2: 0.20278
# [8]	valid_0's rmse: 0.4499	valid_0's l2: 0.20241
# [9]	valid_0's rmse: 0.44957	valid_0's l2: 0.202113
# [10]	valid_0's rmse: 0.449329	valid_0's l2: 0.201896
# [11]	valid_0's rmse: 0.449058	valid_0's l2: 0.201654
# [12]	valid_0's rmse: 0.448905	valid_0's l2: 0.201516
# [13]	valid_0's rmse: 0.448798	valid_0's l2: 0.20142
# [14]	valid_0's rmse: 0.448657	valid_0's l2: 0.201293
# [15]	valid_0's rmse: 0.448589	valid_0's l2: 0.201232
# [16]	valid_0's rmse: 0.4485	valid_0's l2: 0.201152
# [17]	valid_0's rmse: 0.448393	valid_0's l2: 0.201057
# [18]	valid_0's rmse: 0.448332	valid_0's l2: 0.201002
# [19]	valid_0's rmse: 0.448252	valid_0's l2: 0.20093
# [20]	valid_0's rmse: 0.448238	valid_0's l2: 0.200918
# [21]	valid_0's rmse: 0.448158	valid_0's l2: 0.200845
# [22]	valid_0's rmse: 0.448152	valid_0's l2: 0.200841
# [23]	valid_0's rmse: 0.448224	valid_0's l2: 0.200904
# [24]	valid_0's rmse: 0.448165	valid_0's l2: 0.200851
# [25]	valid_0's rmse: 0.448101	valid_0's l2: 0.200794
# [26]	valid_0's rmse: 0.447952	valid_0's l2: 0.200661
# [27]	valid_0's rmse: 0.447851	valid_0's l2: 0.200571
# [28]	valid_0's rmse: 0.447824	valid_0's l2: 0.200546
# [29]	valid_0's rmse: 0.447845	valid_0's l2: 0.200565
# [30]	valid_0's rmse: 0.447873	valid_0's l2: 0.200591
# [31]	valid_0's rmse: 0.447884	valid_0's l2: 0.2006
# [32]	valid_0's rmse: 0.447971	valid_0's l2: 0.200678
# [33]	valid_0's rmse: 0.447999	valid_0's l2: 0.200703
# [34]	valid_0's rmse: 0.447954	valid_0's l2: 0.200663
# [35]	valid_0's rmse: 0.447968	valid_0's l2: 0.200676
# [36]	valid_0's rmse: 0.447926	valid_0's l2: 0.200638
# [37]	valid_0's rmse: 0.447946	valid_0's l2: 0.200656
# [38]	valid_0's rmse: 0.447958	valid_0's l2: 0.200667
# [39]	valid_0's rmse: 0.447986	valid_0's l2: 0.200692
# [40]	valid_0's rmse: 0.448016	valid_0's l2: 0.200719
# [41]	valid_0's rmse: 0.448041	valid_0's l2: 0.200741
# [42]	valid_0's rmse: 0.448056	valid_0's l2: 0.200754
# [43]	valid_0's rmse: 0.448074	valid_0's l2: 0.20077
# [44]	valid_0's rmse: 0.448052	valid_0's l2: 0.20075
# [45]	valid_0's rmse: 0.448053	valid_0's l2: 0.200751
# [46]	valid_0's rmse: 0.448032	valid_0's l2: 0.200732
# [47]	valid_0's rmse: 0.448075	valid_0's l2: 0.200771
# [48]	valid_0's rmse: 0.448091	valid_0's l2: 0.200786
# [49]	valid_0's rmse: 0.448157	valid_0's l2: 0.200845
# [50]	valid_0's rmse: 0.448163	valid_0's l2: 0.20085
# [51]	valid_0's rmse: 0.448205	valid_0's l2: 0.200887
# [52]	valid_0's rmse: 0.448179	valid_0's l2: 0.200865
# [53]	valid_0's rmse: 0.448267	valid_0's l2: 0.200943
# [54]	valid_0's rmse: 0.448253	valid_0's l2: 0.200931
# [55]	valid_0's rmse: 0.448278	valid_0's l2: 0.200953
# [56]	valid_0's rmse: 0.448281	valid_0's l2: 0.200955
# [57]	valid_0's rmse: 0.448301	valid_0's l2: 0.200974
# [58]	valid_0's rmse: 0.448275	valid_0's l2: 0.20095
# [59]	valid_0's rmse: 0.44827	valid_0's l2: 0.200946
# [60]	valid_0's rmse: 0.448298	valid_0's l2: 0.200971
# [61]	valid_0's rmse: 0.448318	valid_0's l2: 0.200989
# [62]	valid_0's rmse: 0.448363	valid_0's l2: 0.20103
# [63]	valid_0's rmse: 0.448401	valid_0's l2: 0.201064
# [64]	valid_0's rmse: 0.448395	valid_0's l2: 0.201058
# [65]	valid_0's rmse: 0.448491	valid_0's l2: 0.201144
# [66]	valid_0's rmse: 0.448496	valid_0's l2: 0.201148
# [67]	valid_0's rmse: 0.44855	valid_0's l2: 0.201197
# [68]	valid_0's rmse: 0.448548	valid_0's l2: 0.201196
# [69]	valid_0's rmse: 0.448517	valid_0's l2: 0.201167
# [70]	valid_0's rmse: 0.448579	valid_0's l2: 0.201223
# [71]	valid_0's rmse: 0.448636	valid_0's l2: 0.201274
# [72]	valid_0's rmse: 0.448635	valid_0's l2: 0.201273
# [73]	valid_0's rmse: 0.448653	valid_0's l2: 0.20129
# [74]	valid_0's rmse: 0.448664	valid_0's l2: 0.2013
# [75]	valid_0's rmse: 0.448644	valid_0's l2: 0.201281
# [76]	valid_0's rmse: 0.448694	valid_0's l2: 0.201326
# [77]	valid_0's rmse: 0.4487	valid_0's l2: 0.201331
# [78]	valid_0's rmse: 0.4487	valid_0's l2: 0.201332
# Early stopping, best iteration is:
# [28]	valid_0's rmse: 0.447824	valid_0's l2: 0.200546
# [1]	valid_0's rmse: 0.455011	valid_0's l2: 0.207035
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's rmse: 0.45378	valid_0's l2: 0.205916
# [3]	valid_0's rmse: 0.452699	valid_0's l2: 0.204937
# [4]	valid_0's rmse: 0.451872	valid_0's l2: 0.204188
# [5]	valid_0's rmse: 0.451187	valid_0's l2: 0.203569
# [6]	valid_0's rmse: 0.450651	valid_0's l2: 0.203086
# [7]	valid_0's rmse: 0.450149	valid_0's l2: 0.202634
# [8]	valid_0's rmse: 0.44977	valid_0's l2: 0.202293
# [9]	valid_0's rmse: 0.449448	valid_0's l2: 0.202004
# [10]	valid_0's rmse: 0.449037	valid_0's l2: 0.201634
# [11]	valid_0's rmse: 0.448812	valid_0's l2: 0.201432
# [12]	valid_0's rmse: 0.448509	valid_0's l2: 0.201161
# [13]	valid_0's rmse: 0.448329	valid_0's l2: 0.200999
# [14]	valid_0's rmse: 0.448101	valid_0's l2: 0.200794
# [15]	valid_0's rmse: 0.447967	valid_0's l2: 0.200674
# [16]	valid_0's rmse: 0.447733	valid_0's l2: 0.200465
# [17]	valid_0's rmse: 0.447656	valid_0's l2: 0.200396
# [18]	valid_0's rmse: 0.447553	valid_0's l2: 0.200304
# [19]	valid_0's rmse: 0.447397	valid_0's l2: 0.200164
# [20]	valid_0's rmse: 0.447322	valid_0's l2: 0.200097
# [21]	valid_0's rmse: 0.447163	valid_0's l2: 0.199955
# [22]	valid_0's rmse: 0.447084	valid_0's l2: 0.199884
# [23]	valid_0's rmse: 0.447094	valid_0's l2: 0.199893
# [24]	valid_0's rmse: 0.447071	valid_0's l2: 0.199872
# [25]	valid_0's rmse: 0.446983	valid_0's l2: 0.199794
# [26]	valid_0's rmse: 0.446893	valid_0's l2: 0.199713
# [27]	valid_0's rmse: 0.446883	valid_0's l2: 0.199704
# [28]	valid_0's rmse: 0.446841	valid_0's l2: 0.199667
# [29]	valid_0's rmse: 0.446858	valid_0's l2: 0.199682
# [30]	valid_0's rmse: 0.446836	valid_0's l2: 0.199663
# [31]	valid_0's rmse: 0.44682	valid_0's l2: 0.199648
# [32]	valid_0's rmse: 0.446815	valid_0's l2: 0.199643
# [33]	valid_0's rmse: 0.446801	valid_0's l2: 0.199631
# [34]	valid_0's rmse: 0.446788	valid_0's l2: 0.19962
# [35]	valid_0's rmse: 0.446743	valid_0's l2: 0.199579
# [36]	valid_0's rmse: 0.446749	valid_0's l2: 0.199585
# [37]	valid_0's rmse: 0.446813	valid_0's l2: 0.199642
# [38]	valid_0's rmse: 0.446733	valid_0's l2: 0.199571
# [39]	valid_0's rmse: 0.446666	valid_0's l2: 0.19951
# [40]	valid_0's rmse: 0.446657	valid_0's l2: 0.199503
# [41]	valid_0's rmse: 0.446616	valid_0's l2: 0.199466
# [42]	valid_0's rmse: 0.446667	valid_0's l2: 0.199512
# [43]	valid_0's rmse: 0.44662	valid_0's l2: 0.19947
# [44]	valid_0's rmse: 0.44664	valid_0's l2: 0.199487
# [45]	valid_0's rmse: 0.446642	valid_0's l2: 0.199489
# [46]	valid_0's rmse: 0.446683	valid_0's l2: 0.199526
# [47]	valid_0's rmse: 0.446712	valid_0's l2: 0.199552
# [48]	valid_0's rmse: 0.446709	valid_0's l2: 0.199549
# [49]	valid_0's rmse: 0.446645	valid_0's l2: 0.199492
# [50]	valid_0's rmse: 0.446677	valid_0's l2: 0.19952
# [51]	valid_0's rmse: 0.446714	valid_0's l2: 0.199554
# [52]	valid_0's rmse: 0.446707	valid_0's l2: 0.199548
# [53]	valid_0's rmse: 0.446692	valid_0's l2: 0.199534
# [54]	valid_0's rmse: 0.446726	valid_0's l2: 0.199564
# [55]	valid_0's rmse: 0.44674	valid_0's l2: 0.199577
# [56]	valid_0's rmse: 0.446706	valid_0's l2: 0.199547
# [57]	valid_0's rmse: 0.446761	valid_0's l2: 0.199595
# [58]	valid_0's rmse: 0.446811	valid_0's l2: 0.19964
# [59]	valid_0's rmse: 0.446777	valid_0's l2: 0.19961
# [60]	valid_0's rmse: 0.446812	valid_0's l2: 0.199641
# [61]	valid_0's rmse: 0.446841	valid_0's l2: 0.199667
# [62]	valid_0's rmse: 0.446879	valid_0's l2: 0.199701
# [63]	valid_0's rmse: 0.446899	valid_0's l2: 0.199719
# [64]	valid_0's rmse: 0.446901	valid_0's l2: 0.19972
# [65]	valid_0's rmse: 0.446882	valid_0's l2: 0.199704
# [66]	valid_0's rmse: 0.446956	valid_0's l2: 0.19977
# [67]	valid_0's rmse: 0.446972	valid_0's l2: 0.199784
# [68]	valid_0's rmse: 0.446984	valid_0's l2: 0.199795
# [69]	valid_0's rmse: 0.446947	valid_0's l2: 0.199762
# [70]	valid_0's rmse: 0.446992	valid_0's l2: 0.199802
# [71]	valid_0's rmse: 0.446989	valid_0's l2: 0.199799
# [72]	valid_0's rmse: 0.447008	valid_0's l2: 0.199817
# [73]	valid_0's rmse: 0.447011	valid_0's l2: 0.199819
# [74]	valid_0's rmse: 0.44708	valid_0's l2: 0.19988
# [75]	valid_0's rmse: 0.447123	valid_0's l2: 0.199919
# [76]	valid_0's rmse: 0.447093	valid_0's l2: 0.199892
# [77]	valid_0's rmse: 0.447134	valid_0's l2: 0.199929
# [78]	valid_0's rmse: 0.44713	valid_0's l2: 0.199925
# [79]	valid_0's rmse: 0.447132	valid_0's l2: 0.199927
# [80]	valid_0's rmse: 0.447148	valid_0's l2: 0.199941
# [81]	valid_0's rmse: 0.447185	valid_0's l2: 0.199975
# [82]	valid_0's rmse: 0.447143	valid_0's l2: 0.199937
# [83]	valid_0's rmse: 0.447227	valid_0's l2: 0.200012
# [84]	valid_0's rmse: 0.447229	valid_0's l2: 0.200013
# [85]	valid_0's rmse: 0.44729	valid_0's l2: 0.200069
# [86]	valid_0's rmse: 0.447294	valid_0's l2: 0.200072
# [87]	valid_0's rmse: 0.447252	valid_0's l2: 0.200034
# [88]	valid_0's rmse: 0.447201	valid_0's l2: 0.199989
# [89]	valid_0's rmse: 0.447211	valid_0's l2: 0.199998
# [90]	valid_0's rmse: 0.447268	valid_0's l2: 0.200049
# [91]	valid_0's rmse: 0.447327	valid_0's l2: 0.200101
# Early stopping, best iteration is:
# [41]	valid_0's rmse: 0.446616	valid_0's l2: 0.199466
# [1]	valid_0's rmse: 0.449281	valid_0's l2: 0.201853
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's rmse: 0.448155	valid_0's l2: 0.200843
# [3]	valid_0's rmse: 0.447187	valid_0's l2: 0.199977
# [4]	valid_0's rmse: 0.446361	valid_0's l2: 0.199238
# [5]	valid_0's rmse: 0.445711	valid_0's l2: 0.198658
# [6]	valid_0's rmse: 0.445212	valid_0's l2: 0.198213
# [7]	valid_0's rmse: 0.444657	valid_0's l2: 0.19772
# [8]	valid_0's rmse: 0.444225	valid_0's l2: 0.197336
# [9]	valid_0's rmse: 0.443832	valid_0's l2: 0.196987
# [10]	valid_0's rmse: 0.443571	valid_0's l2: 0.196755
# [11]	valid_0's rmse: 0.443256	valid_0's l2: 0.196476
# [12]	valid_0's rmse: 0.443045	valid_0's l2: 0.196289
# [13]	valid_0's rmse: 0.442783	valid_0's l2: 0.196056
# [14]	valid_0's rmse: 0.442516	valid_0's l2: 0.19582
# [15]	valid_0's rmse: 0.442402	valid_0's l2: 0.19572
# [16]	valid_0's rmse: 0.442327	valid_0's l2: 0.195653
# [17]	valid_0's rmse: 0.442159	valid_0's l2: 0.195505
# [18]	valid_0's rmse: 0.442108	valid_0's l2: 0.195459
# [19]	valid_0's rmse: 0.442063	valid_0's l2: 0.195419
# [20]	valid_0's rmse: 0.441896	valid_0's l2: 0.195272
# [21]	valid_0's rmse: 0.441787	valid_0's l2: 0.195176
# [22]	valid_0's rmse: 0.441712	valid_0's l2: 0.19511
# [23]	valid_0's rmse: 0.441717	valid_0's l2: 0.195114
# [24]	valid_0's rmse: 0.441736	valid_0's l2: 0.195131
# [25]	valid_0's rmse: 0.441701	valid_0's l2: 0.1951
# [26]	valid_0's rmse: 0.441742	valid_0's l2: 0.195136
# [27]	valid_0's rmse: 0.441707	valid_0's l2: 0.195105
# [28]	valid_0's rmse: 0.441679	valid_0's l2: 0.19508
# [29]	valid_0's rmse: 0.441713	valid_0's l2: 0.195111
# [30]	valid_0's rmse: 0.441741	valid_0's l2: 0.195135
# [31]	valid_0's rmse: 0.44172	valid_0's l2: 0.195116
# [32]	valid_0's rmse: 0.441639	valid_0's l2: 0.195045
# [33]	valid_0's rmse: 0.441575	valid_0's l2: 0.194989
# [34]	valid_0's rmse: 0.441593	valid_0's l2: 0.195004
# [35]	valid_0's rmse: 0.44157	valid_0's l2: 0.194984
# [36]	valid_0's rmse: 0.441589	valid_0's l2: 0.195001
# [37]	valid_0's rmse: 0.441593	valid_0's l2: 0.195004
# [38]	valid_0's rmse: 0.441578	valid_0's l2: 0.194991
# [39]	valid_0's rmse: 0.441614	valid_0's l2: 0.195023
# [40]	valid_0's rmse: 0.441648	valid_0's l2: 0.195053
# [41]	valid_0's rmse: 0.441685	valid_0's l2: 0.195085
# [42]	valid_0's rmse: 0.441642	valid_0's l2: 0.195048
# [43]	valid_0's rmse: 0.441657	valid_0's l2: 0.195061
# [44]	valid_0's rmse: 0.441614	valid_0's l2: 0.195023
# [45]	valid_0's rmse: 0.441597	valid_0's l2: 0.195008
# [46]	valid_0's rmse: 0.441636	valid_0's l2: 0.195042
# [47]	valid_0's rmse: 0.441617	valid_0's l2: 0.195025
# [48]	valid_0's rmse: 0.441636	valid_0's l2: 0.195042
# [49]	valid_0's rmse: 0.441607	valid_0's l2: 0.195016
# [50]	valid_0's rmse: 0.441591	valid_0's l2: 0.195003
# [51]	valid_0's rmse: 0.441555	valid_0's l2: 0.194971
# [52]	valid_0's rmse: 0.44154	valid_0's l2: 0.194958
# [53]	valid_0's rmse: 0.441573	valid_0's l2: 0.194986
# [54]	valid_0's rmse: 0.441609	valid_0's l2: 0.195018
# [55]	valid_0's rmse: 0.441615	valid_0's l2: 0.195024
# [56]	valid_0's rmse: 0.441572	valid_0's l2: 0.194986
# [57]	valid_0's rmse: 0.441626	valid_0's l2: 0.195034
# [58]	valid_0's rmse: 0.441681	valid_0's l2: 0.195082
# [59]	valid_0's rmse: 0.441677	valid_0's l2: 0.195078
# [60]	valid_0's rmse: 0.441744	valid_0's l2: 0.195137
# [61]	valid_0's rmse: 0.441792	valid_0's l2: 0.195181
# [62]	valid_0's rmse: 0.441766	valid_0's l2: 0.195157
# [63]	valid_0's rmse: 0.441832	valid_0's l2: 0.195215
# [64]	valid_0's rmse: 0.441844	valid_0's l2: 0.195226
# [65]	valid_0's rmse: 0.441807	valid_0's l2: 0.195193
# [66]	valid_0's rmse: 0.441811	valid_0's l2: 0.195197
# [67]	valid_0's rmse: 0.441835	valid_0's l2: 0.195218
# [68]	valid_0's rmse: 0.441833	valid_0's l2: 0.195217
# [69]	valid_0's rmse: 0.441867	valid_0's l2: 0.195247
# [70]	valid_0's rmse: 0.44188	valid_0's l2: 0.195258
# [71]	valid_0's rmse: 0.44189	valid_0's l2: 0.195267
# [72]	valid_0's rmse: 0.441952	valid_0's l2: 0.195321
# [73]	valid_0's rmse: 0.442012	valid_0's l2: 0.195375
# [74]	valid_0's rmse: 0.441994	valid_0's l2: 0.195359
# [75]	valid_0's rmse: 0.441993	valid_0's l2: 0.195357
# [76]	valid_0's rmse: 0.44198	valid_0's l2: 0.195346
# [77]	valid_0's rmse: 0.441989	valid_0's l2: 0.195355
# [78]	valid_0's rmse: 0.441996	valid_0's l2: 0.19536
# [79]	valid_0's rmse: 0.441958	valid_0's l2: 0.195327
# [80]	valid_0's rmse: 0.441972	valid_0's l2: 0.19534
# [81]	valid_0's rmse: 0.441976	valid_0's l2: 0.195343
# [82]	valid_0's rmse: 0.44204	valid_0's l2: 0.1954
# [83]	valid_0's rmse: 0.442062	valid_0's l2: 0.195419
# [84]	valid_0's rmse: 0.442061	valid_0's l2: 0.195418
# [85]	valid_0's rmse: 0.442056	valid_0's l2: 0.195414
# [86]	valid_0's rmse: 0.442076	valid_0's l2: 0.195431
# [87]	valid_0's rmse: 0.442051	valid_0's l2: 0.195409
# [88]	valid_0's rmse: 0.442051	valid_0's l2: 0.195409
# [89]	valid_0's rmse: 0.442078	valid_0's l2: 0.195433
# [90]	valid_0's rmse: 0.442099	valid_0's l2: 0.195451
# [91]	valid_0's rmse: 0.442126	valid_0's l2: 0.195475
# [92]	valid_0's rmse: 0.442125	valid_0's l2: 0.195474
# [93]	valid_0's rmse: 0.442149	valid_0's l2: 0.195495
# [94]	valid_0's rmse: 0.442134	valid_0's l2: 0.195483
# [95]	valid_0's rmse: 0.442143	valid_0's l2: 0.19549
# [96]	valid_0's rmse: 0.442133	valid_0's l2: 0.195481
# [97]	valid_0's rmse: 0.442172	valid_0's l2: 0.195516
# [98]	valid_0's rmse: 0.442243	valid_0's l2: 0.195579
# [99]	valid_0's rmse: 0.44228	valid_0's l2: 0.195612
# [100]	valid_0's rmse: 0.442309	valid_0's l2: 0.195637
# Did not meet early stopping. Best iteration is:
# [52]	valid_0's rmse: 0.44154	valid_0's l2: 0.194958
# LGBMRegressor의 5fold 평균 RMSLE는 0.4445887655307518

# %%
submit = pd.read_csv('./data/sample_submission.csv')

# %%
submit.ECLO = np.expm1(prediction)

# %%
submit.hist(bins=100)
plt.show()
# pd.read_csv('./submission/1123.csv').hist(bins=100)
# plt.show()

# %%
submit.to_csv('./submission/1123.csv',index= False)

# %%
import lightgbm as lgb

# 중요도 시각화
lgb.plot_importance(model)  # 상위 10개 피쳐만 표시
plt.show()
